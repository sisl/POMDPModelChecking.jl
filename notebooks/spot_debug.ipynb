# %%
import spot
spot.setup()

# %%
prop = "G !a"

# %%
aut = spot.translate('G a', 'det', 'ba', 'sbacc')
aut
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f308c58fd80> >

# %%
acc = aut.acc()
acc
[s for s in aut.state_acc_sets(0).sets()]
# Out:
# [0]

# %%
aut.acc()
# Out:
# spot.acc_cond(1, "Inf(0)")

# %%
acc.is_rabin_like()
# Out:
# [True, (spot.rs_pair(fin=[], inf=[0]),)]

# %%
dra = spot.to_generalized_rabin(aut)
dra
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f308c59c0f0> >

# %%
dra.acc()
# Out:
# spot.acc_cond(1, "Fin(0)")
